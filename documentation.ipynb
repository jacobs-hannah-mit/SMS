# %%
#hide
from SMS.intersect_annotations import *
from SMS.intersect_annotations import closest_annotation_to_variant

# %% [markdown]
# # Project name here
#
# > Summary description here.

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Install

# %% [markdown]
# `pip install your_project_name`

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
closest_annotation_to_variant()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-a39ec334a10f> in <module>
# ----> 1 closest_annotation_to_variant()
#
# TypeError: closest_annotation_to_variant() missing 5 required positional arguments: 'a_file', 'b_file', 'directory_a', 'directory_b', and 'overlap'
